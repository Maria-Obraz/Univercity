# %% [markdown]
# # Практическая работа №15. Основы ООП. Часть 3
#
# [**Ссылка на код с пары**](https://colab.research.google.com/drive/1iEAmZh8VNbztM_hbQRfUJ35VO-ks54m1?usp=sharing)

# %% [markdown]
# **В коде ниже представлен класс преподавателей и класс студентов (вы можете взять этот код за основу или написать свой).**

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}
 
    def add_courses(self, course_name):
        self.finished_courses.append(course_name)    
 
 
class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []
        
    def rate_hw(self, student, course, grade):
        student.grades[course] = [grade]

# %%
best_student = Student('Ruoy', 'Eman', 'your_gender')
cool_mentor = Mentor('Some', 'Buddy')
cool_mentor.rate_hw(best_student, 'Python', 10)

print("Имя студента: ", best_student.name)
print("Имя преподавателя: ", cool_mentor.name)
print("Оценки студента по курсам: ", best_student.grades)
# Out:
# Имя студента:  Ruoy
# Имя преподавателя:  Some
# Оценки студента по курсам:  {'Python': [10]}

# %% [markdown]
# ## Задание 1. Наследование

# %% [markdown]
# * Класс Mentor должен стать родительским классом для преподавателей. От него нужно реализовать наследование классов Lecturer (лекторы) и Reviewer (эксперты, проверяющие домашние задания).
#
# > Имя, фамилю и список закрепленных курсов логично реализовать на уровне родительского класса.

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def rate_hw(self, student, course, grade):
        student.grades[course] = [grade]

class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.courses_attached = []

class Reviewer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.courses_attached = []


lecturer = Lecturer('Ivan', 'Ivanov')
reviewer = Reviewer('Petr', 'Petrov')

lecturer.courses_attached.append('Python')
reviewer.courses_attached.append('Python')

student = Student('Ruoy', 'Eman', 'your_gender')
student.courses_in_progress.append('Python')

reviewer.rate_hw(student, 'Python', 10)
lecturer.rate_hw(student, 'Python', 9)

print("Имя студента: ", student.name)
print("Оценки студента по курсам: ", student.grades)

print("Имя лектора: ", lecturer.name)
print("Закрепленные курсы лектора: ", lecturer.courses_attached)

print("Имя эксперта: ", reviewer.name)
print("Закрепленные курсы эксперта: ", reviewer.courses_attached)
# Out:
# Имя студента:  Ruoy
# Оценки студента по курсам:  {'Python': [9]}
# Имя лектора:  Ivan
# Закрепленные курсы лектора:  ['Python']
# Имя эксперта:  Petr
# Закрепленные курсы эксперта:  ['Python']

# %% [markdown]
# ## Задание 2. Атрибуты и взаимодействие классов

# %% [markdown]
# * Реализуйте возможность проставления оценок студентам только Reviewer-ам (реализуйте такой метод).
#
# * Реализуйте метод выставления оценок лекторам у класса Student (оценки по 10-балльной шкале, хранятся в атрибуте-словаре у Lecturer, в котором ключи – названия курсов, а значения – списки оценок). Лектор при этом должен быть закреплен за тем курсом, на который записан студент (реализовать проверку).

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)

    def rate_lecture(self, lecturer, course, grade):
        if course in self.courses_in_progress and course in lecturer.courses_attached:
            if course in lecturer.grades:
                lecturer.grades[course].append(grade)
            else:
                lecturer.grades[course] = [grade]
        else:
            print("Ошибка: лектор не закреплен за данным курсом или курс не является курсом студента.")


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def rate_hw(self, student, course, grade):
        student.grades[course] = [grade]

class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.courses_attached = []
        self.grades = {}

class Reviewer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.courses_attached = []

    def rate_student(self, student, course, grade):
        if course in self.courses_attached:
            student.grades[course] = [grade]
        else:
            print("Ошибка: у эксперта нет доступа к данному курсу.")


student = Student('Ruoy', 'Eman', 'your_gender')
student.courses_in_progress.append('Python')

lecturer = Lecturer('Ivan', 'Ivanov')
lecturer.courses_attached.append('Python')

reviewer = Reviewer('Petr', 'Petrov')
reviewer.courses_attached.append('Python')

reviewer.rate_hw(student, 'Python', 10)

lecturer.rate_hw(student, 'Python', 9)

student.rate_lecture(lecturer, 'Python', 8)

print("Имя студента: ", student.name)
print("Оценки студента по курсам: ", student.grades)

print("Имя лектора: ", lecturer.name)
print("Закрепленные курсы лектора: ", lecturer.courses_attached)
print("Оценки лектора по курсам: ", lecturer.grades)

print("Имя эксперта: ", reviewer.name)
print("Закрепленные курсы эксперта: ", reviewer.courses_attached)
# Out:
# Имя студента:  Ruoy
# Оценки студента по курсам:  {'Python': [9]}
# Имя лектора:  Ivan
# Закрепленные курсы лектора:  ['Python']
# Оценки лектора по курсам:  {'Python': [8]}
# Имя эксперта:  Petr
# Закрепленные курсы эксперта:  ['Python']

# %% [markdown]
# ## Задание № 3. Полиморфизм и магические методы

# %% [markdown]
# Перегрузите магический метод \_\_str__ у всех классов.
# У проверяющих он должен выводить информацию в следующем виде:
#
#
#
# ```
# print(some_reviewer)
# Имя: Some
# Фамилия: Buddy
# ```
#
# У лекторов:
#
#
#
# ```
# print(some_lecturer)
# Имя: Some
# Фамилия: Buddy
# Средняя оценка за лекции: 9.9
# ```
#
# А у студентов так:
#
#
#
# ```
# print(some_student)
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашние задания: 9.9
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование
# ```

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)

    def rate_lecture(self, lecturer, course, grade):
        if course in self.courses_in_progress and course in lecturer.courses_attached:
            if course in lecturer.grades:
                lecturer.grades[course].append(grade)
            else:
                lecturer.grades[course] = [grade]
        else:
            print("Ошибка: лектор не закреплен за данным курсом или курс не является курсом студента.")

    def __str__(self):
        grades_lst = []
        for grades in self.grades.values():
            grades_lst += grades
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за домашние задания: {sum(grades_lst) / len(grades_lst)}\nКурсы в процессе изучения: {', '.join(self.courses_in_progress)}\nЗавершенные курсы: {', '.join(self.finished_courses)}"


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def rate_hw(self, student, course, grade):
        student.grades[course] = [grade]

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"

class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.courses_attached = []
        self.grades = {}

    def __str__(self):
        grades_lst = []
        for grades in self.grades.values():
            grades_lst += grades
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за лекции: {sum(grades_lst) / len(grades_lst)}"

class Reviewer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.courses_attached = []

    def rate_student(self, student, course, grade):
        if course in self.courses_attached:
            student.grades[course] = [grade]
        else:
            print("Ошибка: у эксперта нет доступа к данному курсу.")

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"


student = Student('Ruoy', 'Eman', 'your_gender')
student.courses_in_progress.append('Python')

lecturer = Lecturer('Ivan', 'Ivanov')
lecturer.courses_attached.append('Python')

reviewer = Reviewer('Petr', 'Petrov')
reviewer.courses_attached.append('Python')

reviewer.rate_hw(student, 'Python', 10)

lecturer.rate_hw(student, 'Python', 9)

student.rate_lecture(lecturer, 'Python', 8)

print(student)
print(lecturer)
print(reviewer)

# %% [markdown]
# **Реализуйте перегрузку других магических методов на Ваш выбор (не менее трёх), из тех, что были изучены на паре, руководствуясь по смыслу контекстом представленных классов (студенты, преподаватели, оценки и т.д.)**

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)

    def rate_lecture(self, lecturer, course, grade):
        if course in self.courses_in_progress and course in lecturer.courses_attached:
            if course in lecturer.grades:
                lecturer.grades[course].append(grade)
            else:
                lecturer.grades[course] = [grade]
        else:
            print("Ошибка: лектор не закреплен за данным курсом или курс не является курсом студента.")

    def __str__(self):
        grades_lst = []
        for grades in self.grades.values():
            grades_lst += grades
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за домашние задания: {sum(grades_lst) / len(grades_lst)}\nКурсы в процессе изучения: {', '.join(self.courses_in_progress)}\nЗавершенные курсы: {', '.join(self.finished_courses)}"

    def __add__(self, other):
        if isinstance(other, Student):
            total_courses = self.finished_courses + self.courses_in_progress + other.finished_courses + other.courses_in_progress
            return len(set(total_courses))
        else:
            raise TypeError('Объект должен быть типа Student')


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def rate_hw(self, student, course, grade):
        student.grades[course] = [grade]

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"

    def __eq__(self, other):
        if isinstance(other, Mentor):
            return self.name == other.name and self.surname == other.surname
        else:
            return False

class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.courses_attached = []
        self.grades = {}

    def __str__(self):
        grades_lst = []
        for grades in self.grades.values():
            grades_lst += grades
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за лекции: {sum(grades_lst) / len(grades_lst)}"

class Reviewer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.courses_attached = []

    def rate_student(self, student, course, grade):
        if course in self.courses_attached:
            student.grades[course] = [grade]
        else:
            print("Ошибка: у эксперта нет доступа к данному курсу.")

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"

    def __len__(self):
        return len(self.courses_attached)


student1 = Student('Ivan', 'Ivanov', 'male')
student1.finished_courses = ['Python', 'JavaScript']
student1.courses_in_progress = ['Java']

student2 = Student('Petr', 'Petrov', 'male')
student2.finished_courses = ['Python', 'PHP']
student2.courses_in_progress = ['C++']

total_courses = student1 + student2
print(total_courses)

mentor1 = Mentor('Ivan', 'Ivanov')
mentor2 = Mentor('Ivan', 'Ivanov')
mentor3 = Mentor('Petr', 'Petrov')

print(mentor1 == mentor2)
print(mentor1 == mentor3)

reviewer = Reviewer('Petr', 'Petrov')
reviewer.courses_attached = ['Python', 'JavaScript', 'PHP']

print(len(reviewer))
# Out:
# 5
# True
# False
# 3

# %% [markdown]
# ## Задание № 4. Тестирование
#
# Создайте по 2 экземпляра каждого класса, вызовите все созданные методы, а также реализуйте две функции:
#
# * для подсчета средней оценки за домашние задания по всем студентам в рамках конкретного курса (в качестве аргументов принимаем список студентов и название курса);
# * для подсчета средней оценки за лекции всех лекторов в рамках курса (в качестве аргумента принимаем список лекторов и название курса).

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)

    def rate_lecture(self, lecturer, course, grade):
        if course in self.courses_in_progress and course in lecturer.courses_attached:
            if course in lecturer.grades:
                lecturer.grades[course].append(grade)
            else:
                lecturer.grades[course] = [grade]
        else:
            print("Ошибка: лектор не закреплен за данным курсом или курс не является курсом студента.")

    def __str__(self):
        grades_lst = []
        for grades in self.grades.values():
            grades_lst += grades
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за домашние задания: {sum(grades_lst) / len(grades_lst)}\nКурсы в процессе изучения: {', '.join(self.courses_in_progress)}\nЗавершенные курсы: {', '.join(self.finished_courses)}"

    def __add__(self, other):
        if isinstance(other, Student):
            total_courses = self.finished_courses + self.courses_in_progress + other.finished_courses + other.courses_in_progress
            return len(set(total_courses))
        else:
            raise TypeError('Объект должен быть типа Student')


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def rate_hw(self, student, course, grade):
        student.grades[course] = [grade]

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"

    def __eq__(self, other):
        if isinstance(other, Mentor):
            return self.name == other.name and self.surname == other.surname
        else:
            return False

class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.courses_attached = []
        self.grades = {}

    def __str__(self):
        grades_lst = []
        for grades in self.grades.values():
            grades_lst += grades
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за лекции: {sum(grades_lst) / len(grades_lst)}"

class Reviewer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.courses_attached = []

    def rate_student(self, student, course, grade):
        if course in self.courses_attached:
            student.grades[course] = [grade]
        else:
            print("Ошибка: у эксперта нет доступа к данному курсу.")

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"

    def __len__(self):
        return len(self.courses_attached)

student1 = Student('Иван', 'Иванов', 'м')
student1.courses_in_progress = ['Python']
student1.finished_courses = ['Введение в программирование']

student2 = Student('Анна', 'Петрова', 'ж')
student2.courses_in_progress = ['Java']
student2.finished_courses = ['Git']

lecturer1 = Lecturer('Петр', 'Сидоров')
lecturer1.courses_attached = ['Python', 'Git']

lecturer2 = Lecturer('Мария', 'Козлова')
lecturer2.courses_attached = ['Java', 'Введение в программирование']

reviewer1 = Reviewer('Дмитрий', 'Карпов')
reviewer1.courses_attached = ['Python', 'Git']

reviewer2 = Reviewer('Елена', 'Ковалева')
reviewer2.courses_attached = ['Java', 'Введение в программирование']

student1.rate_lecture(lecturer1, 'Python', 9)
student2.rate_lecture(lecturer2, 'Java', 8)

lecturer1.rate_hw(student1, 'Python', 10)
lecturer2.rate_hw(student2, 'Java', 7)

reviewer1.rate_student(student1, 'Python', 8)
reviewer2.rate_student(student2, 'Java', 9)

print(student1)
print()
print(student2)
print()
print(lecturer1)
print()
print(lecturer2)
print()
print(reviewer1)
print()
print(reviewer2)
print()
print(student1 + student2)

student1.courses_in_progress = ["Python", "Git"]
student2.courses_in_progress = ["Python"]

student1.grades = {"Python": [10, 9, 8], "Git": [7, 6, 8]}
student2.grades = {"Python": [9, 8, 9]}

def avg_hw_grade(course, students):
    grades_lst = []
    for student in students:
        if course in student.grades:
            grades_lst += student.grades[course]
    if len(grades_lst) > 0:
        return sum(grades_lst) / len(grades_lst)
    else:
        return 0
students = [student1, student2]
print()
print(avg_hw_grade("Python", students))
print()
print(avg_hw_grade("Git", students))
print()
print(avg_hw_grade("Java", students))
# Out:
# Имя: Иван
# Фамилия: Иванов
# Средняя оценка за домашние задания: 8.0
# Курсы в процессе изучения: Python
# Завершенные курсы: Введение в программирование
#
# Имя: Анна
# Фамилия: Петрова
# Средняя оценка за домашние задания: 9.0
# Курсы в процессе изучения: Java
# Завершенные курсы: Git
#
# Имя: Петр
# Фамилия: Сидоров
# Средняя оценка за лекции: 9.0
#
# Имя: Мария
# Фамилия: Козлова
# Средняя оценка за лекции: 8.0
#
# Имя: Дмитрий
# Фамилия: Карпов
#
# Имя: Елена
# Фамилия: Ковалева
#
# 4
#
# 8.833333333333334
#
# 7.0
#
# 0
